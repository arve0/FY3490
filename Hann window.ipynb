# %%
# %run common.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cos?

# %%
img = imread('MP.tiff')

# %%
center_x, center_y = [ x/2 for x in img.shape ]

# %%
x, y = np.meshgrid(range(img.shape[1]), range(img.shape[0]))
r = np.sqrt((center_x - x)**2 + (center_y - y)**2)
mask = (np.cos(r/center_x*np.pi)+1)/2

# %%
mask[r>center_x] = 0

# %%
wimg = img * mask

# %%
imshow(img)
imshow(wimg)
# Out:
# (<matplotlib.figure.Figure at 0x102fcb750>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11337c550>,
#  <matplotlib.image.AxesImage at 0x113356350>)

# %%
fimg = fftshift(fft2(img))
fwimg = fftshift(fft2(wimg))

# %%
imshow(log(abs(fimg)), cmap="gray")
imshow(log(abs(fwimg)), cmap="gray")
# Out:
# (<matplotlib.figure.Figure at 0x117d0ab90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x130c0a850>,
#  <matplotlib.image.AxesImage at 0x130c24e10>)
