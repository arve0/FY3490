# %%
# %run ../common.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft2', 'imshow', 'imread', 'imsave']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
sobel = np.array([[-1,0,1],
                  [-2,0,2],
                  [-1,0,1]])

# %%
image = imread('../MP.tiff')

# %%
image.shape
# Out:
# (2111, 2198)

# %%
P = image.shape[0] + sobel.shape[0] - 1
Q = image.shape[1] + sobel.shape[1] - 1
P,Q
# Out:
# (2113, 2200)

# %%
numpy.pad?

# %%
# pad with zeros - page 252
padding = ((0,P-sobel.shape[0]), (0,Q-sobel.shape[1]))
sobel_padded = numpy.pad(sobel, pad_width=padding, mode='constant')

# %%
sobel_padded.shape
# Out:
# (2113, 2200)

# %%
padding = ((0,P-image.shape[0]), (0,Q-image.shape[1]))
image_padded = numpy.pad(image, pad_width=padding, mode='constant')

# %%
image_padded.shape
# Out:
# (2113, 2200)

# %%
H = fft2(sobel_padded)
H = 1j*H.imag
specshow(H)
# Out:
# -c:3: RuntimeWarning: divide by zero encountered in log

# %%
F = fft2(image_padded)
specshow(F)

# %%
G = F*H
g = ifft2(G).real
gimshow(g)

# %%
g[100:110,100:110]
# Out:
# array([[ -1.50000000e+00,   7.50000000e+00,   8.50000000e+00,
#          -3.59407513e-14,   4.00000000e+00,   1.35000000e+01,
#           1.30000000e+01,  -5.00000000e-01,  -1.00000000e+01,
#          -8.50000000e+00],
#        [ -1.00000000e+01,   2.00000000e+00,   9.00000000e+00,
#          -3.16364697e-14,   1.50000000e+00,   1.25000000e+01,
#           1.80000000e+01,   5.50000000e+00,  -6.50000000e+00,
#          -1.05000000e+01],
#        [ -8.50000000e+00,   5.00000000e-01,   5.00000000e+00,
#          -2.00000000e+00,  -5.00000000e-01,   6.50000000e+00,
#           1.75000000e+01,   1.30000000e+01,   2.00000000e+00,
#          -9.00000000e+00],
#        [ -3.35733965e-14,   1.50000000e+00,  -2.00000000e+00,
#          -5.00000000e+00,   6.67163648e-15,   1.50000000e+00,
#           1.10000000e+01,   1.55000000e+01,   1.15000000e+01,
#          -2.50000000e+00],
#        [  6.00000000e+00,   2.00000000e+00,  -7.00000000e+00,
#          -5.00000000e+00,   1.50000000e+00,  -5.00000000e-01,
#           4.00000000e+00,   1.10000000e+01,   1.60000000e+01,
#           5.00000000e+00],
#        [  6.00000000e+00,   2.00000000e+00,  -5.50000000e+00,
#          -1.00000000e+00,   2.00000000e+00,  -3.00000000e+00,
#          -1.50000000e+00,   4.00000000e+00,   1.25000000e+01,
#           9.00000000e+00],
#        [  2.00000000e+00,   1.00000000e+00,  -5.00000000e-01,
#           2.00000000e+00,   5.00000000e-01,  -3.50000000e+00,
#          -3.00000000e+00,  -9.46941952e-15,   4.50000000e+00,
#           7.00000000e+00],
#        [ -4.00000000e+00,  -1.50000000e+00,   2.00000000e+00,
#           3.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#          -5.00000000e-01,  -2.00000000e+00,  -4.00000000e+00,
#           5.00000000e-01],
#        [ -7.00000000e+00,  -6.50000000e+00,  -1.00000000e+00,
#           5.00000000e-01,   5.00000000e+00,   6.50000000e+00,
#           2.50000000e+00,  -2.50000000e+00,  -8.50000000e+00,
#          -3.00000000e+00],
#        [ -5.00000000e+00,  -1.10000000e+01,  -6.50000000e+00,
#          -4.00000000e+00,   5.00000000e+00,   9.50000000e+00,
#           4.00000000e+00,  -2.00000000e+00,  -8.00000000e+00,
#          -2.50000000e+00]])

# %%
gimshow(scale(g))

# %%
imsave('sobel.tif', scale(g))
